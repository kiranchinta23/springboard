# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#            City of London Barking & Dagenham     Barnet     Bexley      Brent  \
# NaT             E09000001          E09000002  E09000003  E09000004  E09000005
# 1995-01-01          91449            50460.2    93284.5    64958.1    71306.6
# 1995-02-01        82202.8            51085.8    93190.2    64787.9    72022.3
# 1995-03-01        79120.7              51269    92247.5    64367.5    72015.8
# 1995-04-01        77101.2            53133.5    90762.9    64277.7    72965.6
#
#               Bromley     Camden    Croydon     Ealing    Enfield    ...      \
# NaT         E09000006  E09000007  E09000008  E09000009  E09000010    ...
# 1995-01-01    81671.5     120933    69158.2    79885.9    72514.7    ...
# 1995-02-01    81657.6     119509    68951.1    80897.1    73155.2    ...
# 1995-03-01    81449.3     120282    68712.4    81379.9    72190.4    ...
# 1995-04-01    81124.4     120098      68610    82188.9    71442.9    ...
#
#            NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS  \
# NaT         E12000002          E12000003     E12000004     E12000005
# 1995-01-01    43958.5            44803.4       45544.5       48527.5
# 1995-02-01    43925.4            44528.8       46051.6       49341.3
# 1995-03-01    44434.9            45200.5       45383.8       49442.2
# 1995-04-01    44267.8            45614.3       46124.2       49455.9
#
#            EAST OF ENGLAND     LONDON SOUTH EAST SOUTH WEST Unnamed: 46  \
# NaT              E12000006  E12000007  E12000008  E12000009         NaN
# 1995-01-01         56701.6    74435.8    64018.9    54705.2         NaN
# 1995-02-01         56593.6    72777.9      63715    54356.1         NaN
# 1995-03-01         56171.2    73896.8    64113.6    53583.1         NaN
# 1995-04-01         56567.9    74455.3    64623.2      54786         NaN
#
#               England
# NaT         E92000001
# 1995-01-01    53202.8
# 1995-02-01    53096.2
# 1995-03-01    53201.3
# 1995-04-01    53590.9
#
# [5 rows x 48 columns]

# %%
properties.describe()
# Out:
#        Unnamed: 33  Unnamed: 36  Unnamed: 46
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 302 entries, NaT to 2020-01-01
# Data columns (total 48 columns):
# City of London          302 non-null object
# Barking & Dagenham      302 non-null object
# Barnet                  302 non-null object
# Bexley                  302 non-null object
# Brent                   302 non-null object
# Bromley                 302 non-null object
# Camden                  302 non-null object
# Croydon                 302 non-null object
# Ealing                  302 non-null object
# Enfield                 302 non-null object
# Greenwich               302 non-null object
# Hackney                 302 non-null object
# Hammersmith & Fulham    302 non-null object
# Haringey                302 non-null object
# Harrow                  302 non-null object
# Havering                302 non-null object
# Hillingdon              302 non-null object
# Hounslow                302 non-null object
# Islington               302 non-null object
# Kensington & Chelsea    302 non-null object
# Kingston upon Thames    302 non-null object
# Lambeth                 302 non-null object
# Lewisham                302 non-null object
# Merton                  302 non-null object
# Newham                  302 non-null object
# Redbridge               302 non-null object
# Richmond upon Thames    302 non-null object
# Southwark               302 non-null object
# Sutton                  302 non-null object
# Tower Hamlets           302 non-null object
# Waltham Forest          302 non-null object
# Wandsworth              302 non-null object
# Westminster             302 non-null object
# Unnamed: 33             0 non-null float64
# Inner London            302 non-null object
# Outer London            302 non-null object
# Unnamed: 36             0 non-null float64
# NORTH EAST              302 non-null object
# NORTH WEST              302 non-null object
# YORKS & THE HUMBER      302 non-null object
# EAST MIDLANDS           302 non-null object
# WEST MIDLANDS           302 non-null object
# EAST OF ENGLAND         302 non-null object
# LONDON                  302 non-null object
# SOUTH EAST              302 non-null object
# SOUTH WEST              302 non-null object
# Unnamed: 46             0 non-null float64
# England                 302 non-null object
# dtypes: float64(3), object(45)
# memory usage: 115.6+ KB

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties=properties.transpose()

# %%
properties.head()
# Out:
#                           NaT 1995-01-01 1995-02-01 1995-03-01 1995-04-01  \
# City of London      E09000001      91449    82202.8    79120.7    77101.2
# Barking & Dagenham  E09000002    50460.2    51085.8      51269    53133.5
# Barnet              E09000003    93284.5    93190.2    92247.5    90762.9
# Bexley              E09000004    64958.1    64787.9    64367.5    64277.7
# Brent               E09000005    71306.6    72022.3    72015.8    72965.6
#
#                    1995-05-01 1995-06-01 1995-07-01 1995-08-01 1995-09-01  \
# City of London        84409.1    94900.5     110128     112329     104473
# Barking & Dagenham    53042.2    53700.3    52113.1    52232.2    51471.6
# Barnet                  90258    90107.2    91441.2    92361.3    93273.1
# Bexley                63997.1    64252.3    63722.7    64432.6    64509.5
# Brent                   73704    74310.5      74127      73547    73789.5
#
#                       ...     2019-04-01 2019-05-01 2019-06-01 2019-07-01  \
# City of London        ...         738842     718773     743157     719871
# Barking & Dagenham    ...         296360     296555     295600     299538
# Barnet                ...         512588     503721     511926     514134
# Bexley                ...         339948     337445     339964     338721
# Brent                 ...         487049     482244     472702     470872
#
#                    2019-08-01 2019-09-01 2019-10-01 2019-11-01 2019-12-01  \
# City of London         777613     792034     827093     777610     734872
# Barking & Dagenham     300702     305277     304153     305882     301816
# Barnet                 527996     527115     525739     523582     517986
# Bexley                 338702     334826     334510     334711     336972
# Brent                  486068     500246     494527     431249     431245
#
#                    2020-01-01
# City of London         775309
# Barking & Dagenham     301057
# Barnet                 520682
# Bexley                 331683
# Brent                  408523
#
# [5 rows x 302 columns]

# %%
properties=properties.reset_index()

# %%
properties.head()
# Out:
#                 index        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001               91449             82202.8
# 1  Barking & Dagenham  E09000002             50460.2             51085.8
# 2              Barnet  E09000003             93284.5             93190.2
# 3              Bexley  E09000004             64958.1             64787.9
# 4               Brent  E09000005             71306.6             72022.3
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0             79120.7             77101.2             84409.1
# 1               51269             53133.5             53042.2
# 2             92247.5             90762.9               90258
# 3             64367.5             64277.7             63997.1
# 4             72015.8             72965.6               73704
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0             94900.5              110128              112329
# 1             53700.3             52113.1             52232.2
# 2             90107.2             91441.2             92361.3
# 3             64252.3             63722.7             64432.6
# 4             74310.5               74127               73547
#
#           ...         2019-04-01 00:00:00 2019-05-01 00:00:00  \
# 0         ...                      738842              718773
# 1         ...                      296360              296555
# 2         ...                      512588              503721
# 3         ...                      339948              337445
# 4         ...                      487049              482244
#
#   2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 0              743157              719871              777613
# 1              295600              299538              300702
# 2              511926              514134              527996
# 3              339964              338721              338702
# 4              472702              470872              486068
#
#   2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 0              792034              827093              777610
# 1              305277              304153              305882
# 2              527115              525739              523582
# 3              334826              334510              334711
# 4              500246              494527              431249
#
#   2019-12-01 00:00:00 2020-01-01 00:00:00
# 0              734872              775309
# 1              301816              301057
# 2              517986              520682
# 3              336972              331683
# 4              431245              408523
#
# [5 rows x 303 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
cols=list(properties.columns)

# %%
cols
# Out:
# ['index',
#  NaT,
#  Timestamp('1995-01-01 00:00:00'),
#  Timestamp('1995-02-01 00:00:00'),
#  Timestamp('1995-03-01 00:00:00'),
#  Timestamp('1995-04-01 00:00:00'),
#  Timestamp('1995-05-01 00:00:00'),
#  Timestamp('1995-06-01 00:00:00'),
#  Timestamp('1995-07-01 00:00:00'),
#  Timestamp('1995-08-01 00:00:00'),
#  Timestamp('1995-09-01 00:00:00'),
#  Timestamp('1995-10-01 00:00:00'),
#  Timestamp('1995-11-01 00:00:00'),
#  Timestamp('1995-12-01 00:00:00'),
#  Timestamp('1996-01-01 00:00:00'),
#  Timestamp('1996-02-01 00:00:00'),
#  Timestamp('1996-03-01 00:00:00'),
#  Timestamp('1996-04-01 00:00:00'),
#  Timestamp('1996-05-01 00:00:00'),
#  Timestamp('1996-06-01 00:00:00'),
#  Timestamp('1996-07-01 00:00:00'),
#  Timestamp('1996-08-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-10-01 00:00:00'),
#  Timestamp('1996-11-01 00:00:00'),
#  Timestamp('1996-12-01 00:00:00'),
#  Timestamp('1997-01-01 00:00:00'),
#  Timestamp('1997-02-01 00:00:00'),
#  Timestamp('1997-03-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1997-05-01 00:00:00'),
#  Timestamp('1997-06-01 00:00:00'),
#  Timestamp('1997-07-01 00:00:00'),
#  Timestamp('1997-08-01 00:00:00'),
#  Timestamp('1997-09-01 00:00:00'),
#  Timestamp('1997-10-01 00:00:00'),
#  Timestamp('1997-11-01 00:00:00'),
#  Timestamp('1997-12-01 00:00:00'),
#  Timestamp('1998-01-01 00:00:00'),
#  Timestamp('1998-02-01 00:00:00'),
#  Timestamp('1998-03-01 00:00:00'),
#  Timestamp('1998-04-01 00:00:00'),
#  Timestamp('1998-05-01 00:00:00'),
#  Timestamp('1998-06-01 00:00:00'),
#  Timestamp('1998-07-01 00:00:00'),
#  Timestamp('1998-08-01 00:00:00'),
#  Timestamp('1998-09-01 00:00:00'),
#  Timestamp('1998-10-01 00:00:00'),
#  Timestamp('1998-11-01 00:00:00'),
#  Timestamp('1998-12-01 00:00:00'),
#  Timestamp('1999-01-01 00:00:00'),
#  Timestamp('1999-02-01 00:00:00'),
#  Timestamp('1999-03-01 00:00:00'),
#  Timestamp('1999-04-01 00:00:00'),
#  Timestamp('1999-05-01 00:00:00'),
#  Timestamp('1999-06-01 00:00:00'),
#  Timestamp('1999-07-01 00:00:00'),
#  Timestamp('1999-08-01 00:00:00'),
#  Timestamp('1999-09-01 00:00:00'),
#  Timestamp('1999-10-01 00:00:00'),
#  Timestamp('1999-11-01 00:00:00'),
#  Timestamp('1999-12-01 00:00:00'),
#  Timestamp('2000-01-01 00:00:00'),
#  Timestamp('2000-02-01 00:00:00'),
#  Timestamp('2000-03-01 00:00:00'),
#  Timestamp('2000-04-01 00:00:00'),
#  Timestamp('2000-05-01 00:00:00'),
#  Timestamp('2000-06-01 00:00:00'),
#  Timestamp('2000-07-01 00:00:00'),
#  Timestamp('2000-08-01 00:00:00'),
#  Timestamp('2000-09-01 00:00:00'),
#  Timestamp('2000-10-01 00:00:00'),
#  Timestamp('2000-11-01 00:00:00'),
#  Timestamp('2000-12-01 00:00:00'),
#  Timestamp('2001-01-01 00:00:00'),
#  Timestamp('2001-02-01 00:00:00'),
#  Timestamp('2001-03-01 00:00:00'),
#  Timestamp('2001-04-01 00:00:00'),
#  Timestamp('2001-05-01 00:00:00'),
#  Timestamp('2001-06-01 00:00:00'),
#  Timestamp('2001-07-01 00:00:00'),
#  Timestamp('2001-08-01 00:00:00'),
#  Timestamp('2001-09-01 00:00:00'),
#  Timestamp('2001-10-01 00:00:00'),
#  Timestamp('2001-11-01 00:00:00'),
#  Timestamp('2001-12-01 00:00:00'),
#  Timestamp('2002-01-01 00:00:00'),
#  Timestamp('2002-02-01 00:00:00'),
#  Timestamp('2002-03-01 00:00:00'),
#  Timestamp('2002-04-01 00:00:00'),
#  Timestamp('2002-05-01 00:00:00'),
#  Timestamp('2002-06-01 00:00:00'),
#  Timestamp('2002-07-01 00:00:00'),
#  Timestamp('2002-08-01 00:00:00'),
#  Timestamp('2002-09-01 00:00:00'),
#  Timestamp('2002-10-01 00:00:00'),
#  Timestamp('2002-11-01 00:00:00'),
#  Timestamp('2002-12-01 00:00:00'),
#  Timestamp('2003-01-01 00:00:00'),
#  Timestamp('2003-02-01 00:00:00'),
#  Timestamp('2003-03-01 00:00:00'),
#  Timestamp('2003-04-01 00:00:00'),
#  Timestamp('2003-05-01 00:00:00'),
#  Timestamp('2003-06-01 00:00:00'),
#  Timestamp('2003-07-01 00:00:00'),
#  Timestamp('2003-08-01 00:00:00'),
#  Timestamp('2003-09-01 00:00:00'),
#  Timestamp('2003-10-01 00:00:00'),
#  Timestamp('2003-11-01 00:00:00'),
#  Timestamp('2003-12-01 00:00:00'),
#  Timestamp('2004-01-01 00:00:00'),
#  Timestamp('2004-02-01 00:00:00'),
#  Timestamp('2004-03-01 00:00:00'),
#  Timestamp('2004-04-01 00:00:00'),
#  Timestamp('2004-05-01 00:00:00'),
#  Timestamp('2004-06-01 00:00:00'),
#  Timestamp('2004-07-01 00:00:00'),
#  Timestamp('2004-08-01 00:00:00'),
#  Timestamp('2004-09-01 00:00:00'),
#  Timestamp('2004-10-01 00:00:00'),
#  Timestamp('2004-11-01 00:00:00'),
#  Timestamp('2004-12-01 00:00:00'),
#  Timestamp('2005-01-01 00:00:00'),
#  Timestamp('2005-02-01 00:00:00'),
#  Timestamp('2005-03-01 00:00:00'),
#  Timestamp('2005-04-01 00:00:00'),
#  Timestamp('2005-05-01 00:00:00'),
#  Timestamp('2005-06-01 00:00:00'),
#  Timestamp('2005-07-01 00:00:00'),
#  Timestamp('2005-08-01 00:00:00'),
#  Timestamp('2005-09-01 00:00:00'),
#  Timestamp('2005-10-01 00:00:00'),
#  Timestamp('2005-11-01 00:00:00'),
#  Timestamp('2005-12-01 00:00:00'),
#  Timestamp('2006-01-01 00:00:00'),
#  Timestamp('2006-02-01 00:00:00'),
#  Timestamp('2006-03-01 00:00:00'),
#  Timestamp('2006-04-01 00:00:00'),
#  Timestamp('2006-05-01 00:00:00'),
#  Timestamp('2006-06-01 00:00:00'),
#  Timestamp('2006-07-01 00:00:00'),
#  Timestamp('2006-08-01 00:00:00'),
#  Timestamp('2006-09-01 00:00:00'),
#  Timestamp('2006-10-01 00:00:00'),
#  Timestamp('2006-11-01 00:00:00'),
#  Timestamp('2006-12-01 00:00:00'),
#  Timestamp('2007-01-01 00:00:00'),
#  Timestamp('2007-02-01 00:00:00'),
#  Timestamp('2007-03-01 00:00:00'),
#  Timestamp('2007-04-01 00:00:00'),
#  Timestamp('2007-05-01 00:00:00'),
#  Timestamp('2007-06-01 00:00:00'),
#  Timestamp('2007-07-01 00:00:00'),
#  Timestamp('2007-08-01 00:00:00'),
#  Timestamp('2007-09-01 00:00:00'),
#  Timestamp('2007-10-01 00:00:00'),
#  Timestamp('2007-11-01 00:00:00'),
#  Timestamp('2007-12-01 00:00:00'),
#  Timestamp('2008-01-01 00:00:00'),
#  Timestamp('2008-02-01 00:00:00'),
#  Timestamp('2008-03-01 00:00:00'),
#  Timestamp('2008-04-01 00:00:00'),
#  Timestamp('2008-05-01 00:00:00'),
#  Timestamp('2008-06-01 00:00:00'),
#  Timestamp('2008-07-01 00:00:00'),
#  Timestamp('2008-08-01 00:00:00'),
#  Timestamp('2008-09-01 00:00:00'),
#  Timestamp('2008-10-01 00:00:00'),
#  Timestamp('2008-11-01 00:00:00'),
#  Timestamp('2008-12-01 00:00:00'),
#  Timestamp('2009-01-01 00:00:00'),
#  Timestamp('2009-02-01 00:00:00'),
#  Timestamp('2009-03-01 00:00:00'),
#  Timestamp('2009-04-01 00:00:00'),
#  Timestamp('2009-05-01 00:00:00'),
#  Timestamp('2009-06-01 00:00:00'),
#  Timestamp('2009-07-01 00:00:00'),
#  Timestamp('2009-08-01 00:00:00'),
#  Timestamp('2009-09-01 00:00:00'),
#  Timestamp('2009-10-01 00:00:00'),
#  Timestamp('2009-11-01 00:00:00'),
#  Timestamp('2009-12-01 00:00:00'),
#  Timestamp('2010-01-01 00:00:00'),
#  Timestamp('2010-02-01 00:00:00'),
#  Timestamp('2010-03-01 00:00:00'),
#  Timestamp('2010-04-01 00:00:00'),
#  Timestamp('2010-05-01 00:00:00'),
#  Timestamp('2010-06-01 00:00:00'),
#  Timestamp('2010-07-01 00:00:00'),
#  Timestamp('2010-08-01 00:00:00'),
#  Timestamp('2010-09-01 00:00:00'),
#  Timestamp('2010-10-01 00:00:00'),
#  Timestamp('2010-11-01 00:00:00'),
#  Timestamp('2010-12-01 00:00:00'),
#  Timestamp('2011-01-01 00:00:00'),
#  Timestamp('2011-02-01 00:00:00'),
#  Timestamp('2011-03-01 00:00:00'),
#  Timestamp('2011-04-01 00:00:00'),
#  Timestamp('2011-05-01 00:00:00'),
#  Timestamp('2011-06-01 00:00:00'),
#  Timestamp('2011-07-01 00:00:00'),
#  Timestamp('2011-08-01 00:00:00'),
#  Timestamp('2011-09-01 00:00:00'),
#  Timestamp('2011-10-01 00:00:00'),
#  Timestamp('2011-11-01 00:00:00'),
#  Timestamp('2011-12-01 00:00:00'),
#  Timestamp('2012-01-01 00:00:00'),
#  Timestamp('2012-02-01 00:00:00'),
#  Timestamp('2012-03-01 00:00:00'),
#  Timestamp('2012-04-01 00:00:00'),
#  Timestamp('2012-05-01 00:00:00'),
#  Timestamp('2012-06-01 00:00:00'),
#  Timestamp('2012-07-01 00:00:00'),
#  Timestamp('2012-08-01 00:00:00'),
#  Timestamp('2012-09-01 00:00:00'),
#  Timestamp('2012-10-01 00:00:00'),
#  Timestamp('2012-11-01 00:00:00'),
#  Timestamp('2012-12-01 00:00:00'),
#  Timestamp('2013-01-01 00:00:00'),
#  Timestamp('2013-02-01 00:00:00'),
#  Timestamp('2013-03-01 00:00:00'),
#  Timestamp('2013-04-01 00:00:00'),
#  Timestamp('2013-05-01 00:00:00'),
#  Timestamp('2013-06-01 00:00:00'),
#  Timestamp('2013-07-01 00:00:00'),
#  Timestamp('2013-08-01 00:00:00'),
#  Timestamp('2013-09-01 00:00:00'),
#  Timestamp('2013-10-01 00:00:00'),
#  Timestamp('2013-11-01 00:00:00'),
#  Timestamp('2013-12-01 00:00:00'),
#  Timestamp('2014-01-01 00:00:00'),
#  Timestamp('2014-02-01 00:00:00'),
#  Timestamp('2014-03-01 00:00:00'),
#  Timestamp('2014-04-01 00:00:00'),
#  Timestamp('2014-05-01 00:00:00'),
#  Timestamp('2014-06-01 00:00:00'),
#  Timestamp('2014-07-01 00:00:00'),
#  Timestamp('2014-08-01 00:00:00'),
#  Timestamp('2014-09-01 00:00:00'),
#  Timestamp('2014-10-01 00:00:00'),
#  Timestamp('2014-11-01 00:00:00'),
#  Timestamp('2014-12-01 00:00:00'),
#  Timestamp('2015-01-01 00:00:00'),
#  Timestamp('2015-02-01 00:00:00'),
#  Timestamp('2015-03-01 00:00:00'),
#  Timestamp('2015-04-01 00:00:00'),
#  Timestamp('2015-05-01 00:00:00'),
#  Timestamp('2015-06-01 00:00:00'),
#  Timestamp('2015-07-01 00:00:00'),
#  Timestamp('2015-08-01 00:00:00'),
#  Timestamp('2015-09-01 00:00:00'),
#  Timestamp('2015-10-01 00:00:00'),
#  Timestamp('2015-11-01 00:00:00'),
#  Timestamp('2015-12-01 00:00:00'),
#  Timestamp('2016-01-01 00:00:00'),
#  Timestamp('2016-02-01 00:00:00'),
#  Timestamp('2016-03-01 00:00:00'),
#  Timestamp('2016-04-01 00:00:00'),
#  Timestamp('2016-05-01 00:00:00'),
#  Timestamp('2016-06-01 00:00:00'),
#  Timestamp('2016-07-01 00:00:00'),
#  Timestamp('2016-08-01 00:00:00'),
#  Timestamp('2016-09-01 00:00:00'),
#  Timestamp('2016-10-01 00:00:00'),
#  Timestamp('2016-11-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2017-02-01 00:00:00'),
#  Timestamp('2017-03-01 00:00:00'),
#  Timestamp('2017-04-01 00:00:00'),
#  Timestamp('2017-05-01 00:00:00'),
#  Timestamp('2017-06-01 00:00:00'),
#  Timestamp('2017-07-01 00:00:00'),
#  Timestamp('2017-08-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-10-01 00:00:00'),
#  Timestamp('2017-11-01 00:00:00'),
#  Timestamp('2017-12-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-04-01 00:00:00'),
#  Timestamp('2018-05-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00'),
#  Timestamp('2019-01-01 00:00:00'),
#  Timestamp('2019-02-01 00:00:00'),
#  Timestamp('2019-03-01 00:00:00'),
#  Timestamp('2019-04-01 00:00:00'),
#  Timestamp('2019-05-01 00:00:00'),
#  Timestamp('2019-06-01 00:00:00'),
#  Timestamp('2019-07-01 00:00:00'),
#  Timestamp('2019-08-01 00:00:00'),
#  Timestamp('2019-09-01 00:00:00'),
#  Timestamp('2019-10-01 00:00:00'),
#  Timestamp('2019-11-01 00:00:00'),
#  Timestamp('2019-12-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00')]

# %%
properties.head()
# Out:
#                 index        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001               91449             82202.8
# 1  Barking & Dagenham  E09000002             50460.2             51085.8
# 2              Barnet  E09000003             93284.5             93190.2
# 3              Bexley  E09000004             64958.1             64787.9
# 4               Brent  E09000005             71306.6             72022.3
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0             79120.7             77101.2             84409.1
# 1               51269             53133.5             53042.2
# 2             92247.5             90762.9               90258
# 3             64367.5             64277.7             63997.1
# 4             72015.8             72965.6               73704
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0             94900.5              110128              112329
# 1             53700.3             52113.1             52232.2
# 2             90107.2             91441.2             92361.3
# 3             64252.3             63722.7             64432.6
# 4             74310.5               74127               73547
#
#           ...         2019-04-01 00:00:00 2019-05-01 00:00:00  \
# 0         ...                      738842              718773
# 1         ...                      296360              296555
# 2         ...                      512588              503721
# 3         ...                      339948              337445
# 4         ...                      487049              482244
#
#   2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 0              743157              719871              777613
# 1              295600              299538              300702
# 2              511926              514134              527996
# 3              339964              338721              338702
# 4              472702              470872              486068
#
#   2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 0              792034              827093              777610
# 1              305277              304153              305882
# 2              527115              525739              523582
# 3              334826              334510              334711
# 4              500246              494527              431249
#
#   2019-12-01 00:00:00 2020-01-01 00:00:00
# 0              734872              775309
# 1              301816              301057
# 2              517986              520682
# 3              336972              331683
# 4              431245              408523
#
# [5 rows x 303 columns]

# %%
properties=properties.rename(columns={'index':'Borough',pd.NaT:'ID'})

# %%
properties.head()
# Out:
#               Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001               91449             82202.8
# 1  Barking & Dagenham  E09000002             50460.2             51085.8
# 2              Barnet  E09000003             93284.5             93190.2
# 3              Bexley  E09000004             64958.1             64787.9
# 4               Brent  E09000005             71306.6             72022.3
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0             79120.7             77101.2             84409.1
# 1               51269             53133.5             53042.2
# 2             92247.5             90762.9               90258
# 3             64367.5             64277.7             63997.1
# 4             72015.8             72965.6               73704
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0             94900.5              110128              112329
# 1             53700.3             52113.1             52232.2
# 2             90107.2             91441.2             92361.3
# 3             64252.3             63722.7             64432.6
# 4             74310.5               74127               73547
#
#           ...         2019-04-01 00:00:00 2019-05-01 00:00:00  \
# 0         ...                      738842              718773
# 1         ...                      296360              296555
# 2         ...                      512588              503721
# 3         ...                      339948              337445
# 4         ...                      487049              482244
#
#   2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 0              743157              719871              777613
# 1              295600              299538              300702
# 2              511926              514134              527996
# 3              339964              338721              338702
# 4              472702              470872              486068
#
#   2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 0              792034              827093              777610
# 1              305277              304153              305882
# 2              527115              525739              523582
# 3              334826              334510              334711
# 4              500246              494527              431249
#
#   2019-12-01 00:00:00 2020-01-01 00:00:00
# 0              734872              775309
# 1              301816              301057
# 2              517986              520682
# 3              336972              331683
# 4              431245              408523
#
# [5 rows x 303 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_m=pd.melt(properties,id_vars=['Borough','ID'],value_name='avg price')

# %%
properties_m.head()
# Out:
#               Borough         ID   variable avg price
# 0      City of London  E09000001 1995-01-01     91449
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2
# 2              Barnet  E09000003 1995-01-01   93284.5
# 3              Bexley  E09000004 1995-01-01   64958.1
# 4               Brent  E09000005 1995-01-01   71306.6

# %%
properties_m.columns=['Borough','ID','Month','Avg Price']

# %%
properties_m.head()
# Out:
#               Borough         ID      Month    Avg Price
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 4 columns):
# Borough      14448 non-null category
# ID           13545 non-null object
# Month        14448 non-null datetime64[ns]
# Avg Price    13545 non-null float64
# dtypes: category(1), datetime64[ns](1), float64(1), object(1)
# memory usage: 354.4+ KB

# %%
properties_m['Avg Price']=pd.to_numeric(properties_m['Avg Price'])
properties_m['Borough']=pd.Categorical(properties_m['Borough'])
properties_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 4 columns):
# Borough      14448 non-null category
# ID           13545 non-null object
# Month        14448 non-null datetime64[ns]
# Avg Price    13545 non-null float64
# dtypes: category(1), datetime64[ns](1), float64(1), object(1)
# memory usage: 354.4+ KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties_m['Borough'].unique()
# Out:
# [City of London, Barking & Dagenham, Barnet, Bexley, Brent, ..., LONDON, SOUTH EAST, SOUTH WEST, Unnamed: 46, England]
# Length: 48
# Categories (48, object): [City of London, Barking & Dagenham, Barnet, Bexley, ..., SOUTH EAST, SOUTH WEST, Unnamed: 46, England]

# %%
properties_m[properties_m['Borough'] == 'Unnamed: 46'].head()
# Out:
#          Borough   ID      Month  Avg Price
# 46   Unnamed: 46  NaN 1995-01-01        NaN
# 94   Unnamed: 46  NaN 1995-02-01        NaN
# 142  Unnamed: 46  NaN 1995-03-01        NaN
# 190  Unnamed: 46  NaN 1995-04-01        NaN
# 238  Unnamed: 46  NaN 1995-05-01        NaN

# %%
properties_m[properties_m['Borough'] == 'Unnamed: 36'].head()
# Out:
#          Borough   ID      Month  Avg Price
# 36   Unnamed: 36  NaN 1995-01-01        NaN
# 84   Unnamed: 36  NaN 1995-02-01        NaN
# 132  Unnamed: 36  NaN 1995-03-01        NaN
# 180  Unnamed: 36  NaN 1995-04-01        NaN
# 228  Unnamed: 36  NaN 1995-05-01        NaN

# %%
properties_m[properties_m['Borough'] == 'Unnamed: 33'].head()
# Out:
#          Borough   ID      Month  Avg Price
# 33   Unnamed: 33  NaN 1995-01-01        NaN
# 81   Unnamed: 33  NaN 1995-02-01        NaN
# 129  Unnamed: 33  NaN 1995-03-01        NaN
# 177  Unnamed: 33  NaN 1995-04-01        NaN
# 225  Unnamed: 33  NaN 1995-05-01        NaN

# %%
properties_nnull=properties_m.dropna()

# %%
properties_nnull.Borough.unique()
# Out:
# [City of London, Barking & Dagenham, Barnet, Bexley, Brent, ..., EAST OF ENGLAND, LONDON, SOUTH EAST, SOUTH WEST, England]
# Length: 45
# Categories (45, object): [City of London, Barking & Dagenham, Barnet, Bexley, ..., LONDON, SOUTH EAST, SOUTH WEST, England]

# %%
# A list of non-boroughs. 
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
properties_nb=properties_nnull[~properties_nnull.Borough.isin(nonBoroughs)]

# %%
properties_nb.Borough.unique()
# Out:
# [City of London, Barking & Dagenham, Barnet, Bexley, Brent, ..., Sutton, Tower Hamlets, Waltham Forest, Wandsworth, Westminster]
# Length: 33
# Categories (33, object): [City of London, Barking & Dagenham, Barnet, Bexley, ..., Tower Hamlets, Waltham Forest, Wandsworth, Westminster]

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
properties_sub=properties_nb[properties_nb.Borough=='Brent']


properties_sub.plot(x='Month',y='Avg Price',kind='line')
plt.title('Average House Price By Year')
plt.ylabel('Average House Price ')
# Out:
# Text(0,0.5,'Average House Price ')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
properties_nb['year']=properties_nb['Month'].apply(lambda t:t.year)
properties_nb.head()
# Out:
# /home/kiran/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               Borough         ID      Month    Avg Price  year
# 0      City of London  E09000001 1995-01-01  91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660  1995
# 2              Barnet  E09000003 1995-01-01  93284.51832  1995
# 3              Bexley  E09000004 1995-01-01  64958.09036  1995
# 4               Brent  E09000005 1995-01-01  71306.56698  1995

# %%
dfg=properties_nb.groupby(by=['Borough','year']).mean()
dfg.sample(10)
# Out:
#                                Avg Price
# Borough              year
# Brent                2002  185898.147992
# Richmond upon Thames 2012  454941.838392
# Bromley              2009  249909.335050
# Greenwich            2019  391435.032609
# Bexley               2016  321563.508775
# NORTH WEST           2014            NaN
# SOUTH EAST           2014            NaN
# LONDON               2004            NaN
# Merton               2004  238098.806908
# Brent                2006  253253.437858

# %%
dfg.reset_index(inplace=True)

# %%
dfg.columns
# Out:
# Index(['Borough', 'year', 'Avg Price'], dtype='object')

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(d):
    y1998 = float(d['Avg Price'][d['year']==1998])
    y2018 = float(d['Avg Price'][d['year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
r=create_price_ratio(dfg[dfg.Borough=='Barking & Dagenham'])
r
# Out:
# [4.89661861291754]

# %%
# thorugh entire data frame
final = {}
for b in dfg['Borough'].unique():
    borough = dfg[dfg['Borough'] == b]
    final[b] = create_price_ratio(borough)

print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'EAST MIDLANDS': [nan], 'EAST OF ENGLAND': [nan], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'England': [nan], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Inner London': [nan], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'LONDON': [nan], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'NORTH EAST': [nan], 'NORTH WEST': [nan], 'Newham': [5.305390437201879], 'Outer London': [nan], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'SOUTH EAST': [nan], 'SOUTH WEST': [nan], 'Southwark': [5.516485302379376], 'Sutton': [4.118522608573157], 'Tower Hamlets': [4.62670104006116], 'Unnamed: 33': [nan], 'Unnamed: 36': [nan], 'Unnamed: 46': [nan], 'WEST MIDLANDS': [nan], 'Waltham Forest': [5.83475580932281], 'Wandsworth': [4.757709347739269], 'Westminster': [5.353565392605413], 'YORKS & THE HUMBER': [nan]}

# %%
df_ratios=pd.DataFrame(final)
df_ratios
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon  EAST MIDLANDS  EAST OF ENGLAND  \
# 0         5.30162   4.2011            NaN              NaN
#
#           ...            Sutton  Tower Hamlets  Unnamed: 33  Unnamed: 36  \
# 0         ...          4.118523       4.626701          NaN          NaN
#
#    Unnamed: 46  WEST MIDLANDS  Waltham Forest  Wandsworth  Westminster  \
# 0          NaN            NaN        5.834756    4.757709     5.353565
#
#    YORKS & THE HUMBER
# 0                 NaN
#
# [1 rows x 48 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
df_ratios.rename(columns={'index':'Borough', 0:'ratio'}, inplace=True)
df_ratios.head()
# Out:
#               Borough     ratio
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
top15 = df_ratios.sort_values(by='ratio',ascending=False).head(15)
print(top15)
# Out:
#                  Borough     ratio
# 14               Hackney  6.198286
# 44        Waltham Forest  5.834756
# 37             Southwark  5.516485
# 27              Lewisham  5.449221
# 46           Westminster  5.353565
# 31                Newham  5.305390
# 6         City of London  5.301620
# 16              Haringey  5.134625
# 23  Kensington & Chelsea  5.082465
# 26               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 22             Islington  4.844048
# 13             Greenwich  4.763036

# %%
ax = top15[['Borough','ratio']].plot(kind='bar')

ax.set_xticklabels(top15.Borough)
# Out:
# [Text(0,0,'Hackney'),
#  Text(0,0,'Waltham Forest'),
#  Text(0,0,'Southwark'),
#  Text(0,0,'Lewisham'),
#  Text(0,0,'Westminster'),
#  Text(0,0,'Newham'),
#  Text(0,0,'City of London'),
#  Text(0,0,'Haringey'),
#  Text(0,0,'Kensington & Chelsea'),
#  Text(0,0,'Lambeth'),
#  Text(0,0,'Camden'),
#  Text(0,0,'Barking & Dagenham'),
#  Text(0,0,'Brent'),
#  Text(0,0,'Islington'),
#  Text(0,0,'Greenwich')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ## top 15 places that increases the prices from 1998 to 2018 rapidly
